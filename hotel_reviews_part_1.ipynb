# %% [markdown]
# ## BAIT580 - MBAN - Sauder School of Business
# # Group Assignment - Data Dictionary and Jupyter Notebook Draft

# %% [markdown]
# ## Team 2's Members:
# - Meysam Bavafa meysam.bavafa@gmail.com
# - Garvit Chawla garvitchawla93@gmail.com
# - Isha Goyal goyalisha4742@gmail.com
# - Nhung Nguyen nhungnguyen2012@gmail.com
# - Angela Wang angelawang9808@gmail.com

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <h3> <a href="#overview"> 1. Overview <span class="tocSkip"></span></a></h3>
# <h3> <a href="#problem"> 2. Problem Statements (revisited) <span class="tocSkip"></span></a></h3>
# <h3> <a href="#collab"> 3. Collaboration Statement <span class="tocSkip"></span></a></h3>
# <h3> <a href="#DS"> 4. Dataset Identification<span class="tocSkip"></span></a></h3>
# <h3> <a href="#DD"> 5. Data Dictionary <span class="tocSkip"></span></a></h3>
# <h3> <a href="#defn"> 6. Table Definition <span class="tocSkip"></span></a></h3>
# <h3> <a href="#next"> 7. Next steps <span class="tocSkip"></span></a></h3>
# <h3> <a href="#ref"> 8. References <span class="tocSkip"></span></a></h3>

# %% [markdown]
# <a id="overview"> </a>

# %% [markdown]
# ## 1. Overview
#
# With the advent of growing online portals such as Tripadvisor, Booking.com - there is a surge in reliance of both consumers and businesses on the impact generated by the online reviews. Additionally, the reviews provide a rich data source for applications in Natural Language Understanding, Sentiment analysis, and many more state-of-the-art AI and analytics functions.
#
# We started with thinking about "cleanliness" and "hygiene" as two main focuses for determining the problems faced by the hospitality sectors, supported by research on how these factors influence customer decision-making in choosing their place of stay. Specifically, Hospitalitynet (2018) indicates that 71% of guests expect "above average" cleanliness ratings when choosing hotels.
#
# As we explored further, we could find rich data sources for determining even more factors that might play a great role in influencing the online reviews and ratings provided by the customers. For this deliverable, we aim to introduce two relevant data sources - the first one is the publicly available 515,000 review data and the second one is Smith Travel Research's (STR) hotel chain classification. They provide the solid ground for us to reframe our business problems. Exploring actual available datasets, we would expand our scopes to start with a macro view of the issues in different segments dictated by the STR chain hotel list, further, we aim to pinpoint major reasons that lead to customer satisfaction/dissatisfaction.
#
# This notebook presents a template and outlines how we found, defined the datasets for the above explained analysis. This notebook is developed for Python 3.7+, and expects a standard Jupyter Hub environment.

# %% [markdown]
# <a id="problem"> </a>

# %% [markdown]
# ## 2. Problem Statement (revisited)
#
# Our original business questions stated our interest in finding a strategy to deal with pest infestations in chain hotels. With our further research and availability of richer datasets, we revisited the context of the business question focusing on chain hotels in Europe.
#
# There are 3 questions we aim to answer from our analysis:
#
# 1 - What are the keywords that are majorly contained in customer reviews that lead to satisfaction/dissatisfaction based on the 515,000 reviews dataset?
#
# 2 - Do the hotels with brand names from reputable chains have fewer negative reviews? Are the hotels with more premium brand names having fewer customers' complaints? (Segmentation taken from STR chain scales dataset)
#
# 3 - Is there any identified seasonality (monthly or quarterly) in guests' complaints/negative reviews?
#
# Please note that, with this revised statement, some suggestions that we made in the first proposal are not doable. We can’t calculate the response rate since there are no data on the review's replies and the timeline of analysis changed from 2019-2021 to 2016-2017.

# %% [markdown]
# <a id="collab"> </a>

# %% [markdown]
# ## 3. Collaboration Statement
# Our teamwork distribution is indicated as below:
#
# Meysam identified proper variables for use and indicated each variable with important information in the data dictionary. He also looked into the next steps the group needs to take for the final deliverable.
#
# Garvit created three tables using proper SQL queries that shows properly normalized data structure and drew an ERD diagram to show relationships between tables.
#
# Isha searched for potential datasets and generated a list of unique hotels for our future analysis. She also filtered the hotel location data based on the region we decided to focus on.
#
# Nhung searched for potential datasets and identified the two datasets that are most related to the question. In addition, she reframed the questions based on the adjusted scope of the problem.
#
# Angela worked on the data dictionary and added details such as variable type and sample values. She further refined the dictionary with the proper format based on the three tables.
#
# Tasks for the final deliverable will be allocated during the next group meeting scheduled next week.
#
# Meeting cadence: Five members of the group decide on the cadence of two meetings weekly to collaborate on this project

# %% [markdown]
# <a id="DS"> </a>

# %% [markdown]
# ## 4. Dataset Identification
#
# The two major data sources we have identified are as follows:
#
# #### Dataset 1:
#
# **Title: Enriched Hotel Reviews Dataset**
#
# Rationale: Comprehensive dataset for reviews from Booking.com, which is known to have the most comprehensive end-to-end reviews system. It ensures that the guest's stays are properly verified and the reviews are recorded in a structured format. The dataset is also comparatively clean and structured hence we do not need to spend time cleaning it but rather understanding its format and potential insights.
#
# Use: This is our primary dataset, we would need this for answering all our questions underlined in the previous section. Specifically, we are interested in the review contents and whether they are positive (driving higher satisfaction) or negative (indicating dissatisfied customers).
#
# Limitation: The timeframe of this data set is approximately 4 years ago so some of the trends might not be as relevant as of now.
#
# URI: https://www.kaggle.com/ycalisar/hotel-reviews-dataset-enriched
#
# Keywords: hotel reviews, hospitality, guests in hotels
#
# Publication Date: 16 December 2017
#
# Publisher: Yanir
#
# Creator: Booking.com
#
# Contact Point: Yanir
#
# Spatial Coverage: Europe
#
# Temporal Coverage: 2017
#
# Language: English
#
# Date & Time Formats
#
# Data Version: 1.0
#
# Access Date: 13 January 2022
#
# #### Dataset 2:
#
# **Title: STR Chain Scales Dataset**
#
# Rationale: Smith Travel Research (STR) is an unrivaled business intelligence in chain hotel reporting. Hence, their data is known for accuracy and used as a benchmark for the hospitality industry.
#
# Use: This dataset helps us define a clear scale of the chain hotels as recognized in the industry. We use this to define segmentation for specifically answering the second question of our problem statement as defined in the previous section.
#
# Limitation: The list is made in 2019 hence it is 2 years gap with our first dataset. There might be some changes in hotel chains in between, such as closure of hotels or hotel name change.
#
# URI: https://str.com/sites/default/files/2019-07/str_chain_scales_2019_13.xlsx
#
# Keywords: hospitality intelligence benchmark, hotels chain ranking, hotel industry data
#
# Publication Date: 01 September 2019
#
# Publisher: STR
#
# Creator: STR
#
# Contact Point: https://str.com/contact
#
# Spatial Coverage: Global
#
# Temporal Coverage: September 2019
#
# Language: English
#
# Date & Time Formats
#
# Data Version: 1.0
#
# Access Date: 13 January 2022

# %% [markdown]
# <a id="DD"> </a>

# %% [markdown]
# ## 5. Data Dictionary
# We have defined the data dictionary based on our 3 normalized tables (steps for normalization discussed in sections below) that we need to answer the analysis questions defined above. Furthermore, we converted variables to lower case and remove certain special symbols which are not allowed to comply with the requirements of PostgreSQL. We also define the relevant data types that are allowed in PostgreSQL.
#
# The tables below are generated by Tables Generator Tool (2022).
#
# **Table 1: Hotel Details and their data dictionary:**
# This gives the summary of how many hotels we have in our data and their associated information such as location, aggregated rating/reviews to benchmark our analysis.
#
# |  # | Variable Name   | Source                 | Source variable name    | Variable type (Postgres variable type) | Meaning and purpose                   | Use                      | Holds sensitive data | Sample value or values                                   |
# |:--:|-----------------|------------------------|-------------------------|----------------------------------------|---------------------------------------|--------------------------|----------------------|----------------------------------------------------------|
# |  1 | hotelid         |  defined with schema |  defined with schema  |                   int                  |              Hotel index              |    Identifiy the hotel   |          No          |                             1                            |
# |  2 | hotel           | hotel_reviews_enriched | Hotel_Name              |                  text                  |               Hotel name              |    Identifiy the hotel   |          No          |                        Hotel Arena                       |
# |  3 | address         | hotel_reviews_enriched | Hotel_Address           |                  text                  |             Hotel address             |    Identifiy the hotel   |          No          | s Gravesandestraat 55 Oost 1092 AA Amsterdam Netherlands |
# |  4 | country         | hotel_reviews_enriched | Hotel_Country           |                  text                  |             Hotel country             |    Identifiy the hotel   |          No          |                            NL                            |
# |  5 | state           | hotel_reviews_enriched | Hotel_State             |                  text                  |              Hotel state              |    Identifiy the hotel   |          No          |                            NH                            |
# |  6 | city            | hotel_reviews_enriched | Hotel_City              |                  text                  |               Hotel city              |    Identifiy the hotel   |          No          |                         Amsterdam                        |
# |  7 | lat             | hotel_reviews_enriched | Hotel_lat               |                 float8                 |           Latitude of hotel           |    Identifiy the hotel   |          No          |                        52.3605759                        |
# |  8 | lng             | hotel_reviews_enriched | Hotel_lng               |                 float8                 |           Longitude of hotel          |    Identifiy the hotel   |          No          |                         4.9159683                        |
# |  9 | ttl_num_reviews | hotel_reviews_enriched | Total_Number_of_Reviews |                   int                  | Total number of reviews for the hotel | Reference for comparison |          No          |                           1403                           |
# | 10 | avg_score       | hotel_reviews_enriched | Average_Score           |                   int                  |       Average score of the hotel      |      Final Analysis      |          No          |                             8                            |
#
#
# **Table 2: Review ID and their dictionary:**
# This table and the first table of hotel details (using join statement) would be instrumental in answering all the questions we define here.
#
# |  # | Variable Name           | Source                 | Source variable name                       | Variable type (Postgres variable type) | Meaning and purpose                          | Use                                          | Holds sensitive data | Sample value or values                                                                                |
# |:--:|-------------------------|------------------------|--------------------------------------------|----------------------------------------|----------------------------------------------|----------------------------------------------|----------------------|-------------------------------------------------------------------------------------------------------|
# |  1 | reviewid                |  defined with schema |            defined with schema           |                 serial                 |           Review unique identifier           |             Identify each review             |          No          |                                                   2                                                   |
# |  2 | hotelid                 |  defined with schema |            defined with schema           |                 serial                 |                  Hotel index                 |              Identifiy the hotel             |          No          |                                                   1                                                   |
# |  3 | room_type               | hotel_reviews_enriched | Room_Type                                  |                  text                  |                 Type of room                 | Check problem happen for which type of rooms |          No          |                                           Duplex Double Room                                          |
# |  4 | room_type_level         | hotel_reviews_enriched | Room_Type_Level                            |                  text                  |              Level of room type              | Check problem happen for which type of rooms |          No          |                                                 Duplex                                                |
# |  5 | bed_type                | hotel_reviews_enriched | Bed_Type                                   |                  text                  |                   Bed type                   |               Review assesment               |          No          |                                                 Double                                                |
# |  6 | guest_type              | hotel_reviews_enriched | Guest_Type                                 |                  text                  |                  Guest type                  |         Customer behavioural analysis        |          No          |                                                 Couple                                                |
# |  7 | trip_type               | hotel_reviews_enriched | Trip_Type                                  |                  text                  |                   Trip type                  |         Customer behavioural analysis        |          No          |                                              Leisure trip                                             |
# |  8 | review_date             | hotel_reviews_enriched | Review_Date                                |                timestamp               |            Date review was posted            |               Review assesment               |          No          |                                                20170803                                               |
# |  9 | review_is_positive      | hotel_reviews_enriched | Review_Is_Positive                         |                  bool                  |           If the review is positive          |               Review sentiment               |          No          |                                                   0                                                   |
# | 10 | review_positivity       | hotel_reviews_enriched | Review_Positivity                          |                 float8                 |               Positivity score               |               Review sentiment               |          No          |                                                2.69608                                                |
# | 11 | reviewer_nationality    | hotel_reviews_enriched | Reviewer_Nationality                       |                  text                  |            Nationality of reviewer           |         Customer behavioural analysis        |          No          |                                                Ireland                                                |
# | 12 | reviewer_country        | hotel_reviews_enriched | Reviewer_Country                           |                  text                  |              Country of reviewer             |         Customer behavioural analysis        |          No          |                                                   IE                                                  |
# | 13 | negative_review         | hotel_reviews_enriched | Negative_Review                            |                  text                  |               Negativity score               |               Review sentiment               |          No          | I am so angry that i made this post available via all possible sites i use when planing my trips so … |
# | 14 | negative_word_counts    | hotel_reviews_enriched | Review_Total_Nega                          |                   int                  |         Review's negative word count         |               Review sentiment               |          No          |                                                  397                                                  |
# | 15 | positive_review         | hotel_reviews_enriched | Positive_Review                            |                  text                  |        Content of the positive review        |               Review sentiment               |          No          |                              The park outside of the hotel was beautiful                              |
# | 16 | positive_word_count     | hotel_reviews_enriched | Review_Total_Positive_Word_Count           |                   int                  |         Review's positive word count         |               Review sentiment               |          No          |                                                   11                                                  |
# | 17 | reviewer_score          | hotel_reviews_enriched | Reviewer_Score                             |                   int                  |   The score the reviewer gave to the hotel   |         Customer behavioural analysis        |          No          |                                                   3                                                   |
# | 18 | reviewers_total_contrib | hotel_reviews_enriched | Total_Number_of_Reviews_Reviewer_Has_Given |                   int                  | Total number of reviews a reviewer has given |         Customer behavioural analysis        |          No          |                                                   7                                                   |
#
# **Table 3: Hotel chains and their dictionary:**
# This table helps us filter the location-based hotels of interest to us, further aids in giving us chain scale as segments for answering the second question we defined above.
#
# |  # | Variable Name     | Source                | Source variable name    | Variable type (Postgres variable type) | Meaning and purpose                      | Use                            | Holds sensitive data | Sample value or values   |
# |:--:|-------------------|-----------------------|-------------------------|----------------------------------------|------------------------------------------|--------------------------------|----------------------|--------------------------|
# |  1 | id                | defined with schema |  defined with schema  |                   int                  |          Hotel chain identifier          |    Identify the hotel chain    |          No          |             2            |
# |  2 | scale_id          |    STR Chain Scales   | Scale ID                |                   int                  |   The chain scale the hotel belongs to   | Classify the hotel chain level |          No          |             3            |
# |  3 | chain_scale       |    STR Chain Scales   | Chain Scale             |                  text                  |     Level of the hotel's chain scale     | Classify the hotel chain level |          No          |       Luxury Chains      |
# |  4 | affiliation_name  |    STR Chain Scales   | Affiliation Name        |                  text                  |          Hotel affiliation name          |    Identify the hotel chain    |          No          | 3 Palms Hotels & Resorts |
# |  5 | parent_company    |    STR Chain Scales   | Aff Parent Company Name |                  text                  |            Parent company name           |    Identify the hotel chain    |          No          |  Red Lion Hotels Company |
# |  6 | africa            |    STR Chain Scales   | Africa                  |                  bool                  | If hotel chain has branchs in this area? |   Hotel continent (location)   |          No          |          0 or 1          |
# |  7 | apac              |    STR Chain Scales   | APAC                    |                  bool                  | If hotel chain has branchs in this area? |   Hotel continent (location)   |          No          |          0 or 1          |
# |  8 | cs_america        |    STR Chain Scales   | C&S America             |                  bool                  | If hotel chain has branchs in this area? |   Hotel continent (location)   |          No          |          0 or 1          |
# |  9 | europe            |    STR Chain Scales   | Europe                  |                  bool                  | If hotel chain has branchs in this area? |   Hotel continent (location)   |          No          |          0 or 1          |
# | 10 | middle_east       |    STR Chain Scales   | Middle East             |                  bool                  | If hotel chain has branchs in this area? |   Hotel continent (location)   |          No          |          0 or 1          |
# | 11 | n_america_excl_us |    STR Chain Scales   | North America Excl US   |                  bool                  | If hotel chain has branchs in this area? |   Hotel continent (location)   |          No          |          0 or 1          |
# | 12 | united_states     |    STR Chain Scales   | United States           |                  bool                  | If hotel chain has branchs in this area? |   Hotel continent (location)   |          No          |          0 or 1          |

# %% [markdown]
# <a id="defn"> </a>

# %% [markdown]
# ## 6. Table Definition
# Queries defining the database schema and creation of normalized tables in our database.

# %%
# connecting to the database
import os
import psycopg2
from dotenv import load_dotenv

load_dotenv()

conString = {'host':os.environ.get('DB_HOST'),
             'dbname':os.environ.get('DB_NAME'),
             'user':os.environ.get('DB_USER'),
             'password':os.environ.get('DB_PASS'),
             'port':os.environ.get('DB_PORT')}

conn = psycopg2.connect(**conString)
cur = conn.cursor()

# %%
# Query to define schema
query = """CREATE SCHEMA IF NOT EXISTS grproject"""

# execute the query
cur.execute(query)
# commit
conn.commit()

# %%
# Query to create a table for storing the hotel information
q1_hotel_info = """CREATE TABLE IF NOT EXISTS grproject.hotel_dim(
                        hotelid serial PRIMARY KEY,
                        hotel text NOT NULL UNIQUE,
                        address text,
                        country text,
                        state text,
                        city text,
                        lat float8,
                        lng float8,
                        ttl_num_reviews int CHECK (ttl_num_reviews > 0),
                        avg_score float4 CHECK (avg_score > 0));"""

# execute the query
cur.execute(q1_hotel_info)
# commit
conn.commit()

# %%
# Query to create a table for storing all reviews
q2_review_main = """CREATE TABLE IF NOT EXISTS grproject.reviews_all(
                        reviewid serial PRIMARY KEY,
                        hotelid serial REFERENCES grproject.hotel_dim (hotelid),
                        room_type text,
                        room_type_level text,
                        bed_type text,
                        guest_type text,
                        trip_type text,
                        review_date timestamp NOT NULL,
                        review_is_positive bool,
                        review_positivity float8,
                        reviewer_nationality text,
                        reviewer_country text,
                        negative_review text,
                        negative_word_counts int,
                        positive_review text,
                        positive_word_count int,
                        reviewer_score int CHECK (reviewer_score > 0),
                        reviewers_total_contrib int CHECK (reviewers_total_contrib > 0));"""

# execute the query
cur.execute(q2_review_main)
# commit
conn.commit()

# %%
# Query to create a table for storing mapping of hotels to continents
q3_hotel_list = """CREATE TABLE IF NOT EXISTS grproject.str_chain_list(
                    scale_id int PRIMARY KEY,
                    chain_scale text NOT NULL,
                    affiliation_name text REFERENCES grproject.hotel_dim (hotel),
                    parent_company text,
                    africa bool,
                    apac bool,
                    cs_america bool,
                    europe bool,
                    middle_east bool,
                    n_america_excl_us bool,
                    united_states bool);"""

# execute the query
cur.execute(q3_hotel_list)
# commit
conn.commit()

# %%
cur.close()
conn.close()

# %% [markdown]
# #### ERD representation of the database:

# %% [markdown]
# ![ERD_2.png](attachment:384578d4-6445-4e70-80fd-d0418cf5f5bf.png)

# %% [markdown]
# <a id="next"> </a>

# %% [markdown]
# ## 7. Next steps
# In the next step for this project, we are going to dive deeper into the data and extract insights from it, with a focus on the questions we defined above.
# The idea is to utilize the text of the reviews to carve out the main factors that residents of the hotels care most about during their stay - both positive and negative. We will prepare our final report as a Python code containing the relevant PostgreSQL queries in addition to our final presentation. We are going to present our key findings regarding the core drivers of customer satisfaction or challenges - the business can focus on major problems, we also want to check how these factors change with different segments and time. Moreover, we will investigate the potential impact of the hotel's brand (Chain hotels v.s. individual establishments) on the volume and sentiment of user complaints

# %% [markdown]
# <a id="ref"> </a>

# %% [markdown]
# ## 8. References
# List of relevant references.
#
# 1. Hospitality Net. (2018, 9 April( Do you know the factors that affect guest experience? Retrieved January 20, 2022, https://www.hospitalitynet.org/news/4087829.html
# 2. Orkin. (2017, August 8). Orkin reveals financial impact of bed bug infestations in hotels. Retrieved January 6, 2022,
# from https://www.orkin.com/press-room/financial-impact-bed-bug-infestations
# 3. Smith Travel Research (2022), https://str.com/data-insights/resources/faq
# 4. Tables Generator (2022), https://www.tablesgenerator.com/markdown_tables
